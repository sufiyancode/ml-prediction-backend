# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/finalTrain.csv")

# %%
data_copy = data

# %%
data_copy
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0xcdcd      DEHRES17DEL01                 36.0
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          4.2            30.327968             78.046106
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
#Gives ow many rows ans col dataste contains
data_copy.shape
# Out:
# (45584, 20)

# %%
#To get info about data set use
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
data_copy.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %%
#T for transphose
data_copy.describe().T
# Out:
#                                count       mean        std        min  \
# Delivery_person_Age          43730.0  29.566911   5.815064  15.000000
# Delivery_person_Ratings      43676.0   4.633774   0.334744   1.000000
# Restaurant_latitude          45584.0  17.017948   8.185674 -30.905562
# Restaurant_longitude         45584.0  70.229684  22.885575 -88.366217
# Delivery_location_latitude   45584.0  17.465480   7.335562   0.010000
# Delivery_location_longitude  45584.0  70.844161  21.120578   0.010000
# Vehicle_condition            45584.0   1.023385   0.839055   0.000000
# multiple_deliveries          44591.0   0.744635   0.572510   0.000000
# Time_taken (min)             45584.0  26.293963   9.384298  10.000000
#
#                                    25%        50%        75%        max
# Delivery_person_Age          25.000000  30.000000  35.000000  50.000000
# Delivery_person_Ratings       4.500000   4.700000   4.900000   6.000000
# ...

# %%
data_copy['Delivery_person_Ratings'].count()
# Out:
# 43676

# %%
data_copy['Delivery_person_Age'].mean()
# Out:
# 29.566910587697233

# %%
data_copy['Delivery_person_Age'].std()
# Out:
# 5.815063854587488

# %%
data_copy.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %% [markdown]
# # Check Duplicate

# %%
#No duplicated data in these data set
data_copy[data_copy.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min)]
# Index: []

# %% [markdown]
# # Fill NAN values

# %%
#Check for null values
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['Delivery_person_Age'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Delivery_person_Age']
# Out:
# 0        36.0
# 1        21.0
# 2        23.0
# 3        34.0
# 4        24.0
#          ...
# 45579    30.0
# 45580    21.0
# 45581    30.0
# 45582    20.0
# 45583    23.0
# Name: Delivery_person_Age, Length: 45584, dtype: float64

# %%
data_copy['Delivery_person_Age'].unique()
# Out:
# array([36., 21., 23., 34., 24., 29., 35., 33., 25., 31., 37., 27., 32.,
#        26., 38., 20., 22., nan, 28., 39., 30., 15., 50.])

# %%
np.mean(data_copy['Delivery_person_Age'])
# Out:
# 29.566910587697233

# %%
np.median(data_copy['Delivery_person_Age'])
# Out:
# nan

# %%
data_copy['Delivery_person_Age'].fillna(np.mean(data_copy['Delivery_person_Age']),inplace=True)

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['Delivery_person_Ratings'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Delivery_person_Ratings'].unique()
# Out:
# array([4.2, 4.7, 4.3, 4.5, 4. , 4.9, 4.1, 5. , 4.8, 3.5, 4.6, nan, 4.4,
#        3.8, 3.9, 3.7, 2.6, 2.5, 3.6, 3.1, 2.7, 1. , 3.2, 3.3, 6. , 3.4,
#        2.8, 2.9, 3. ])

# %%
np.mean(data_copy['Delivery_person_Ratings'])
# Out:
# 4.633773697225019

# %%
np.median(data_copy['Delivery_person_Ratings'])
# Out:
# nan

# %%
data_copy['Delivery_person_Ratings'].fillna(np.mean(data_copy['Delivery_person_Ratings']),inplace=True)

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['Time_Orderd'].dtype
# Out:
# dtype('O')

# %%
data_copy['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
import statistics
statistics.mode(data_copy['Time_Orderd'])
# Out:
# nan

# %%
data_copy['Time_Orderd']=data_copy['Time_Orderd'].str.replace(":",".")

# %%
data_copy['Time_Orderd']
# Out:
# 0        21.55
# 1        14.55
# 2        17.30
# 3        09.20
# 4        19.50
#          ...
# 45579    11.35
# 45580    19.55
# 45581    23.50
# 45582    13.35
# 45583    17.10
# Name: Time_Orderd, Length: 45584, dtype: object

# %%
data_copy['Time_Orderd'] = data_copy['Time_Orderd'].astype('float')

# %%
data_copy['Time_Orderd'].dtype
# Out:
# dtype('float64')

# %%
np.mean(data_copy['Time_Orderd'])
# Out:
# 16.3119501516427

# %%
np.median(data_copy['Time_Orderd'])
# Out:
# nan

# %%
data_copy['Time_Orderd'].fillna(np.mean(data_copy['Time_Orderd']),inplace=True)

# %%
data_copy['Time_Orderd'].isnull().sum()
# Out:
# 0

# %%
data_copy['Time_Orderd']
# Out:
# 0        21.55
# 1        14.55
# 2        17.30
# 3         9.20
# 4        19.50
#          ...
# 45579    11.35
# 45580    19.55
# 45581    23.50
# 45582    13.35
# 45583    17.10
# Name: Time_Orderd, Length: 45584, dtype: float64

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['Weather_conditions']
# Out:
# 0               Fog
# 1            Stormy
# 2        Sandstorms
# 3        Sandstorms
# 4               Fog
#             ...
# 45579         Windy
# 45580         Windy
# 45581        Cloudy
# 45582        Cloudy
# 45583           Fog
# Name: Weather_conditions, Length: 45584, dtype: object

# %%
statistics.mode(data_copy['Weather_conditions'])
# Out:
# 'Fog'

# %%
data_copy['Weather_conditions'].fillna(statistics.mode(data_copy['Weather_conditions']),inplace=True)

# %%
data_copy['Weather_conditions'].isnull().sum()
# Out:
# 0

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['Road_traffic_density']
# Out:
# 0           Jam
# 1          High
# 2        Medium
# 3           Low
# 4           Jam
#           ...
# 45579      High
# 45580       Jam
# 45581       Low
# 45582      High
# 45583    Medium
# Name: Road_traffic_density, Length: 45584, dtype: object

# %%
statistics.mode(data_copy['Road_traffic_density'])
# Out:
# 'Low'

# %%
data_copy['Road_traffic_density'].fillna(statistics.mode(data_copy['Road_traffic_density']),inplace=True)

# %%
data_copy['Road_traffic_density'].isnull().sum()
# Out:
# 0

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['multiple_deliveries']
# Out:
# 0        3.0
# 1        1.0
# 2        1.0
# 3        0.0
# 4        1.0
#         ...
# 45579    0.0
# 45580    1.0
# 45581    0.0
# 45582    1.0
# 45583    1.0
# Name: multiple_deliveries, Length: 45584, dtype: float64

# %%
np.mean(data_copy['multiple_deliveries'])
# Out:
# 0.7446345675136238

# %%
np.median(data_copy['multiple_deliveries'])
# Out:
# nan

# %%
data_copy['multiple_deliveries'].unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
data_copy['multiple_deliveries'].fillna(2.0,inplace=True)

# %%
data_copy['multiple_deliveries'].unique()
# Out:
# array([3., 1., 0., 2.])

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['Festival']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 45579    No
# 45580    No
# 45581    No
# 45582    No
# 45583    No
# Name: Festival, Length: 45584, dtype: object

# %%
data_copy['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
statistics.mode(data_copy['Festival'])
# Out:
# 'No'

# %%
data_copy['Festival'].fillna(statistics.mode(data_copy['Festival']),inplace=True)

# %%
data_copy['Festival'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data_copy.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age               0
# Delivery_person_Ratings           0
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                       0
# Time_Order_picked                 0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries               0
# Festival                          0
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
data_copy['City']
# Out:
# 0        Metropolitian
# 1        Metropolitian
# 2        Metropolitian
# 3        Metropolitian
# 4        Metropolitian
#              ...
# 45579    Metropolitian
# 45580    Metropolitian
# 45581    Metropolitian
# 45582    Metropolitian
# 45583    Metropolitian
# Name: City, Length: 45584, dtype: object

# %%
data_copy['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban', nan], dtype=object)

# %%
statistics.mode(data_copy['City'])
# Out:
# 'Metropolitian'

# %%
data_copy['City'].fillna(statistics.mode(data_copy['City']),inplace=True)

# %%
data_copy.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64

# %% [markdown]
# # Separate Numerical and Categorical Features

# %%
numerical_features = []
categorical_features = []
for i in data_copy.columns:
    if data_copy[i].dtype == 'O':
        categorical_features.append(i)
    else:
        numerical_features.append(i)

# %%
numerical_features
# Out:
# ['Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Time_Orderd',
#  'Vehicle_condition',
#  'multiple_deliveries',
#  'Time_taken (min)']

# %%
categorical_features
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Order_Date',
#  'Time_Order_picked',
#  'Weather_conditions',
#  'Road_traffic_density',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'Festival',
#  'City']

# %% [markdown]
# # Data Visualization

# %%
#This is for a show distributin and QQPlot diagram
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,plot=pylab)
    plt.show()

# %%
for i in numerical_features:
    plot_data(data_copy[i])

# %%
plt.figure(figsize=(8,6))
for i in numerical_features:
    sns.histplot(data=data_copy,x=i,kde=True)
    print('\n')
    plt.show()

# %% [markdown]
# **EDA**
#
# > Add blockquote

# %%
data_copy.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
# ...

# %%
data_copy['ID']
# Out:
# 0        0xcdcd
# 1        0xd987
# 2        0x2784
# 3        0xc8b6
# 4        0xdb64
#           ...
# 45579    0x7c09
# 45580    0xd641
# 45581    0x4f8d
# 45582    0x5eee
# 45583    0x5fb2
# Name: ID, Length: 45584, dtype: object

# %%
data_copy['ID'].count()
# Out:
# 45584

# %%
len(data_copy['ID'].unique())
# Out:
# 45584

# %%
data_copy = data_copy.drop(columns=['ID'])

# %%
data_copy.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd Time_Order_picked  \
# ...

# %%
data_copy['Delivery_person_ID'].unique()
# Out:
# array(['DEHRES17DEL01', 'KOCRES16DEL01', 'PUNERES13DEL03', ...,
#        'KOCRES04DEL01', 'BHPRES06DEL03', 'GOARES03DEL03'], dtype=object)

# %%
data_copy['Delivery_person_ID']
# Out:
# 0           DEHRES17DEL01
# 1           KOCRES16DEL01
# 2          PUNERES13DEL03
# 3          LUDHRES15DEL02
# 4           KNPRES14DEL02
#                ...
# 45579       JAPRES04DEL01
# 45580       AGRRES16DEL01
# 45581      CHENRES08DEL03
# 45582     COIMBRES11DEL01
# 45583    RANCHIRES09DEL02
# Name: Delivery_person_ID, Length: 45584, dtype: object

# %%
len(data_copy['Delivery_person_ID'].unique())
# Out:
# 1320

# %%
frequency_encoding = data_copy['Delivery_person_ID'].value_counts().to_dict()

# %%
frequency_encoding
# Out:
# {'JAPRES11DEL02': 67,
#  'PUNERES01DEL01': 67,
#  'VADRES11DEL02': 66,
#  'VADRES08DEL02': 66,
#  'JAPRES03DEL01': 66,
#  'RANCHIRES02DEL01': 66,
#  'HYDRES04DEL02': 66,
#  'VADRES14DEL01': 65,
#  'RANCHIRES02DEL02': 65,
#  'SURRES11DEL01': 65,
#  'JAPRES09DEL02': 65,
#  'INDORES08DEL02': 65,
#  'INDORES15DEL01': 65,
#  'VADRES11DEL01': 65,
#  'BANGRES03DEL01': 65,
#  'BANGRES07DEL02': 65,
#  'MUMRES14DEL02': 64,
#  'RANCHIRES16DEL01': 64,
#  'MUMRES02DEL02': 64,
#  'COIMBRES010DEL02': 64,
#  'VADRES12DEL02': 64,
#  'HYDRES12DEL02': 64,
#  'MUMRES01DEL01': 63,
#  'INDORES03DEL02': 63,
#  'BANGRES16DEL02': 63,
#  'SURRES01DEL02': 63,
#  'JAPRES14DEL02': 63,
#  'JAPRES17DEL01': 63,
#  'HYDRES11DEL02': 63,
#  'MYSRES14DEL01': 63,
#  'SURRES010DEL02': 63,
#  'PUNERES17DEL01': 63,
#  'COIMBRES02DEL01': 63,
#  'JAPRES20DEL02': 63,
#  'BANGRES09DEL01': 63,
#  'HYDRES08DEL02': 63,
#  'CHENRES12DEL02': 63,
#  'MYSRES05DEL01': 63,
#  'RANCHIRES14DEL02': 63,
#  'MYSRES04DEL02': 63,
# ...

# %%
data_copy['Delivery_person_ID_encoded'] = data_copy['Delivery_person_ID'].map(frequency_encoding)

# %%
data_copy['Delivery_person_ID_encoded']
# Out:
# 0        12
# 1        13
# 2        39
# 3        15
# 4        13
#          ..
# 45579    60
# 45580    13
# 45581    44
# 45582    62
# 45583    61
# Name: Delivery_person_ID_encoded, Length: 45584, dtype: int64

# %%
data_copy.drop(columns="Delivery_person_ID",axis=1,inplace=True)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022        21.55             22:10
# 1                    76.347589  13-02-2022        14.55             15:05
# ...

# %%
data_copy['Delivery_person_Age'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Delivery_person_Ratings'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Restaurant_latitude'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Restaurant_longitude'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Delivery_location_latitude'].dtype
# Out:
# dtype('float64')

# %%
data_copy['Delivery_location_longitude'].dtype
# Out:
# dtype('float64')

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022        21.55             22:10
# 1                    76.347589  13-02-2022        14.55             15:05
# ...

# %%
data_copy['Order_Date'].dtype
# Out:
# dtype('O')

# %%
data_copy['Order_Date'].str.split('-')
# Out:
# 0        [12, 02, 2022]
# 1        [13, 02, 2022]
# 2        [04, 03, 2022]
# 3        [13, 02, 2022]
# 4        [14, 02, 2022]
#               ...
# 45579    [24, 03, 2022]
# 45580    [16, 02, 2022]
# 45581    [11, 03, 2022]
# 45582    [07, 03, 2022]
# 45583    [02, 03, 2022]
# Name: Order_Date, Length: 45584, dtype: object

# %%
data_copy['Day'] = data_copy['Order_Date'].str.split('-').str[0]

# %%
data_copy['Month'] = data_copy['Order_Date'].str.split('-').str[1]
data_copy['Year'] = data_copy['Order_Date'].str.split('-').str[2]

# %%
data_copy['Day'] =  data_copy['Day'].astype(int)

# %%
data_copy['Month'] = data_copy['Month'].astype(int)
data_copy['Year'] = data_copy['Year'].astype(int)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          45584 non-null  float64
#  1   Delivery_person_Ratings      45584 non-null  float64
#  2   Restaurant_latitude          45584 non-null  float64
#  3   Restaurant_longitude         45584 non-null  float64
#  4   Delivery_location_latitude   45584 non-null  float64
#  5   Delivery_location_longitude  45584 non-null  float64
#  6   Order_Date                   45584 non-null  object
#  7   Time_Orderd                  45584 non-null  float64
#  8   Time_Order_picked            45584 non-null  object
#  9   Weather_conditions           45584 non-null  object
#  10  Road_traffic_density         45584 non-null  object
#  11  Vehicle_condition            45584 non-null  int64
# ...

# %%
data_copy.drop(columns="Order_Date",axis=1,inplace=True)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Time_Orderd Time_Order_picked  \
# 0                    78.116106        21.55             22:10
# 1                    76.347589        14.55             15:05
# ...

# %%
data_copy['Weather_conditions']
# Out:
# 0               Fog
# 1            Stormy
# 2        Sandstorms
# 3        Sandstorms
# 4               Fog
#             ...
# 45579         Windy
# 45580         Windy
# 45581        Cloudy
# 45582        Cloudy
# 45583           Fog
# Name: Weather_conditions, Length: 45584, dtype: object

# %%
data_copy['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
data_copy['Weather_conditions'].value_counts()
# Out:
# Fog           8269
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: Weather_conditions, dtype: int64

# %%
# Assuming data_copy is your DataFrame
data_copy = pd.get_dummies(data_copy, columns=['Weather_conditions'])

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Time_Orderd Time_Order_picked  \
# 0                    78.116106        21.55             22:10
# 1                    76.347589        14.55             15:05
# ...

# %%
data_copy['Time_Orderd'] =  data_copy['Time_Orderd'].astype('O')

# %%
data_copy['Time_Orderd'].dtype
# Out:
# dtype('O')

# %%
data_copy['Time_Orderd']
# Out:
# 0        21.55
# 1        14.55
# 2         17.3
# 3          9.2
# 4         19.5
#          ...
# 45579    11.35
# 45580    19.55
# 45581     23.5
# 45582    13.35
# 45583     17.1
# Name: Time_Orderd, Length: 45584, dtype: object

# %%
data_copy['Time_Orderd'].apply(lambda x: f"{x:.2f}")
# Out:
# 0        21.55
# 1        14.55
# 2        17.30
# 3         9.20
# 4        19.50
#          ...
# 45579    11.35
# 45580    19.55
# 45581    23.50
# 45582    13.35
# 45583    17.10
# Name: Time_Orderd, Length: 45584, dtype: object

# %%
data_copy['Time_Orderd'] = data_copy['Time_Orderd'].apply(lambda x: f"{x:.2f}")

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# 0                    78.116106       21.55             22:10
# 1                    76.347589       14.55             15:05
# ...

# %%
data_copy[['Time_Orderd_Hour', 'Time_Orderd_Minute']] = data_copy['Time_Orderd'].str.split('.', expand=True)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# 0                    78.116106       21.55             22:10
# 1                    76.347589       14.55             15:05
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Delivery_person_Age            45584 non-null  float64
#  1   Delivery_person_Ratings        45584 non-null  float64
#  2   Restaurant_latitude            45584 non-null  float64
#  3   Restaurant_longitude           45584 non-null  float64
#  4   Delivery_location_latitude     45584 non-null  float64
#  5   Delivery_location_longitude    45584 non-null  float64
#  6   Time_Orderd                    45584 non-null  object
#  7   Time_Order_picked              45584 non-null  object
#  8   Road_traffic_density           45584 non-null  object
#  9   Vehicle_condition              45584 non-null  int64
#  10  Type_of_order                  45584 non-null  object
#  11  Type_of_vehicle                45584 non-null  object
# ...

# %%
data_copy['Time_Orderd_Hour'].isnull().sum()
# Out:
# 0

# %%
data_copy['Time_Orderd_Minute'].isnull().sum()
# Out:
# 0

# %%
# Convert hours and minutes to integers
data_copy['Time_Orderd_Hour'] = data_copy['Time_Orderd_Hour'].astype(int)
data_copy['Time_Orderd_Minute'] = data_copy['Time_Orderd_Minute'].astype(int)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked  \
# 0                    78.116106       21.55             22:10
# 1                    76.347589       14.55             15:05
# ...

# %%
data_copy.drop(columns="Time_Orderd",axis=1,inplace=True)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Order_picked Road_traffic_density  \
# 0                    78.116106             22:10                  Jam
# 1                    76.347589             15:05                 High
# ...

# %%
# data_copy.drop(columns="Hour",axis=1,inplace=True)
# data_copy.drop(columns="Minute",axis=1,inplace=True)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Order_picked Road_traffic_density  \
# 0                    78.116106             22:10                  Jam
# 1                    76.347589             15:05                 High
# ...

# %%
data_copy['Time_Order_picked'].dtype
# Out:
# dtype('O')

# %%
data_copy['Time_Order_picked_Hour'] =  data_copy['Time_Order_picked'].str.split(':').str[0]

# %%
data_copy['Time_Order_picked_Hour'].isnull().sum()
# Out:
# 0

# %%
data_copy['Time_Order_picked_Min'] =  data_copy['Time_Order_picked'].str.split(':').str[1]

# %%
data_copy['Time_Order_picked_Min'].isnull().sum()
# Out:
# 4127

# %%
data_copy['Time_Order_picked_Min'].unique()
# Out:
# array(['10', '05', '40', '30', '35', '50', '25', '45', '55', nan, '15',
#        '20'], dtype=object)

# %%
data_copy['Time_Order_picked_Min'].fillna("00",inplace=True)

# %%
data_copy['Time_Order_picked_Min'].isnull().sum()
# Out:
# 0

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Order_picked Road_traffic_density  \
# 0                    78.116106             22:10                  Jam
# 1                    76.347589             15:05                 High
# ...

# %%
data_copy.drop(columns="Time_Order_picked",axis=1,inplace=True)

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Road_traffic_density  Vehicle_condition  \
# 0                    78.116106                  Jam                  2
# 1                    76.347589                 High                  1
# ...

# %%
data_copy['Road_traffic_density']
# Out:
# 0           Jam
# 1          High
# 2        Medium
# 3           Low
# 4           Jam
#           ...
# 45579      High
# 45580       Jam
# 45581       Low
# 45582      High
# 45583    Medium
# Name: Road_traffic_density, Length: 45584, dtype: object

# %%
data_copy['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

data_copy['Road_traffic_density'] = label_encoder.fit_transform(data_copy['Road_traffic_density'])

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Road_traffic_density  Vehicle_condition  \
# 0                    78.116106                     1                  2
# 1                    76.347589                     0                  1
# ...

# %%
data_copy['Vehicle_condition'].dtype
# Out:
# dtype('int64')

# %%
data_copy['Type_of_order'].unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
# 'Type_of_order'= ['Snack', 'Meal', 'Drinks', 'Buffet', 'Snack', 'Meal']
# Assuming data_copy is your DataFrame
data_copy = pd.get_dummies(data_copy, columns=['Type_of_order'])

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Road_traffic_density  Vehicle_condition  \
# 0                    78.116106                     1                  2
# 1                    76.347589                     0                  1
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Delivery_person_Age            45584 non-null  float64
#  1   Delivery_person_Ratings        45584 non-null  float64
#  2   Restaurant_latitude            45584 non-null  float64
#  3   Restaurant_longitude           45584 non-null  float64
#  4   Delivery_location_latitude     45584 non-null  float64
#  5   Delivery_location_longitude    45584 non-null  float64
#  6   Road_traffic_density           45584 non-null  int32
#  7   Vehicle_condition              45584 non-null  int64
#  8   Type_of_vehicle                45584 non-null  object
#  9   multiple_deliveries            45584 non-null  float64
#  10  Festival                       45584 non-null  object
#  11  City                           45584 non-null  object
# ...

# %%
data_copy['Type_of_vehicle']
# Out:
# 0        motorcycle
# 1        motorcycle
# 2           scooter
# 3        motorcycle
# 4           scooter
#             ...
# 45579    motorcycle
# 45580    motorcycle
# 45581       scooter
# 45582    motorcycle
# 45583       scooter
# Name: Type_of_vehicle, Length: 45584, dtype: object

# %%
data_copy['Type_of_vehicle'].unique()
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter', 'bicycle'],
#       dtype=object)

# %%
# One-hot encoding using pandas
data_copy = pd.get_dummies(data_copy, columns=['Type_of_vehicle'])

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Road_traffic_density              45584 non-null  int32
#  7   Vehicle_condition                 45584 non-null  int64
#  8   multiple_deliveries               45584 non-null  float64
#  9   Festival                          45584 non-null  object
#  10  City                              45584 non-null  object
# ...

# %%
data_copy['Festival'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Label encoding using pandas
data_copy['Festival'] = data_copy['Festival'].map({'No': 0, 'Yes': 1})

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Road_traffic_density              45584 non-null  int32
#  7   Vehicle_condition                 45584 non-null  int64
#  8   multiple_deliveries               45584 non-null  float64
#  9   Festival                          45584 non-null  int64
#  10  City                              45584 non-null  object
# ...

# %%
data_copy['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
# Fit and transform the data
data_copy['City'] = label_encoder.fit_transform(data_copy['City'])

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Road_traffic_density              45584 non-null  int32
#  7   Vehicle_condition                 45584 non-null  int64
#  8   multiple_deliveries               45584 non-null  float64
#  9   Festival                          45584 non-null  int64
#  10  City                              45584 non-null  int32
# ...

# %%
data_copy.isnull().sum()
# Out:
# Delivery_person_Age                 0
# Delivery_person_Ratings             0
# Restaurant_latitude                 0
# Restaurant_longitude                0
# Delivery_location_latitude          0
# Delivery_location_longitude         0
# Road_traffic_density                0
# Vehicle_condition                   0
# multiple_deliveries                 0
# Festival                            0
# City                                0
# Time_taken (min)                    0
# Delivery_person_ID_encoded          0
# Day                                 0
# Month                               0
# Year                                0
# Weather_conditions_Cloudy           0
# Weather_conditions_Fog              0
# Weather_conditions_Sandstorms       0
# Weather_conditions_Stormy           0
# Weather_conditions_Sunny            0
# Weather_conditions_Windy            0
# Time_Orderd_Hour                    0
# Time_Orderd_Minute                  0
# Time_Order_picked_Hour              0
# ...

# %%
data_copy.isnull().sum()
# Out:
# Delivery_person_Age                 0
# Delivery_person_Ratings             0
# Restaurant_latitude                 0
# Restaurant_longitude                0
# Delivery_location_latitude          0
# Delivery_location_longitude         0
# Road_traffic_density                0
# Vehicle_condition                   0
# multiple_deliveries                 0
# Festival                            0
# City                                0
# Time_taken (min)                    0
# Delivery_person_ID_encoded          0
# Day                                 0
# Month                               0
# Year                                0
# Weather_conditions_Cloudy           0
# Weather_conditions_Fog              0
# Weather_conditions_Sandstorms       0
# Weather_conditions_Stormy           0
# Weather_conditions_Sunny            0
# Weather_conditions_Windy            0
# Time_Orderd_Hour                    0
# Time_Orderd_Minute                  0
# Time_Order_picked_Hour              0
# ...

# %%
import numpy as np
# Set the earth's radius (in kilometers)
R = 6371

# Convert degrees to radians
def deg_to_rad(degrees):
    return degrees * (np.pi/180)

# Function to calculate the distance between two points using the haversine formula
def distcalculate(lat1, lon1, lat2, lon2):
    d_lat = deg_to_rad(lat2-lat1)
    d_lon = deg_to_rad(lon2-lon1)
    a = np.sin(d_lat/2)**2 + np.cos(deg_to_rad(lat1)) * np.cos(deg_to_rad(lat2)) * np.sin(d_lon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c
  
# Calculate the distance between each pair of points
data_copy['distance'] = np.nan

for i in range(len(data)):
    data_copy.loc[i, 'distance'] = distcalculate(data_copy.loc[i, 'Restaurant_latitude'], 
                                        data_copy.loc[i, 'Restaurant_longitude'], 
                                        data_copy.loc[i, 'Delivery_location_latitude'], 
                                        data_copy.loc[i, 'Delivery_location_longitude'])

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Road_traffic_density              45584 non-null  int32
#  7   Vehicle_condition                 45584 non-null  int64
#  8   multiple_deliveries               45584 non-null  float64
#  9   Festival                          45584 non-null  int64
#  10  City                              45584 non-null  int32
# ...

# %%
data_copy.isnull().sum()!=0
# Out:
# Delivery_person_Age                 False
# Delivery_person_Ratings             False
# Restaurant_latitude                 False
# Restaurant_longitude                False
# Delivery_location_latitude          False
# Delivery_location_longitude         False
# Road_traffic_density                False
# Vehicle_condition                   False
# multiple_deliveries                 False
# Festival                            False
# City                                False
# Time_taken (min)                    False
# Delivery_person_ID_encoded          False
# Day                                 False
# Month                               False
# Year                                False
# Weather_conditions_Cloudy           False
# Weather_conditions_Fog              False
# Weather_conditions_Sandstorms       False
# Weather_conditions_Stormy           False
# Weather_conditions_Sunny            False
# Weather_conditions_Windy            False
# ...

# %%
# Save the DataFrame to a CSV file
data_copy.to_csv('zomato_clean.csv', index=False)
