# %%
import pandas as pd

# %%
data = pd.read_csv("zomato_clean.csv")

# %%
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Road_traffic_density  Vehicle_condition  \
# 0                    78.116106                     1                  2
# 1                    76.347589                     0                  1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Road_traffic_density              45584 non-null  int64
#  7   Vehicle_condition                 45584 non-null  int64
#  8   multiple_deliveries               45584 non-null  float64
#  9   Festival                          45584 non-null  int64
#  10  City                              45584 non-null  int64
# ...

# %%
data.corr()
# Out:
#                                   Delivery_person_Age  \
# Delivery_person_Age                          1.000000
# Delivery_person_Ratings                     -0.067909
# Restaurant_latitude                         -0.004201
# Restaurant_longitude                        -0.008604
# Delivery_location_latitude                   0.002452
# Delivery_location_longitude                 -0.000497
# Road_traffic_density                        -0.003710
# Vehicle_condition                            0.003030
# multiple_deliveries                          0.102262
# Festival                                     0.057044
# City                                        -0.059848
# Time_taken (min)                             0.292886
# Delivery_person_ID_encoded                  -0.007959
# Day                                          0.003110
# Month                                       -0.006977
# Year                                              NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
# data_copy = pd.read_csv('your_dataset.csv')  # Example of loading data

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Visualize the correlation matrix
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Delivery_person_Age (0.292886): Moderate positive correlation.
# Delivery_person_Ratings (-0.331137): Moderate negative correlation.
# multiple_deliveries (0.346913): Moderate positive correlation.
# Festival (0.290070): Moderate positive correlation.
# Road_traffic_density (-0.182994): Weak to moderate negative correlation.
# Vehicle_condition (-0.234456): Moderate negative correlation.
# Type_of_vehicle_motorcycle (0.164200): Weak to moderate positive correlation.
# Type_of_vehicle_scooter (-0.137302): Weak to moderate negative correlation.
#
# Based on these observations,I selecting the following features for further analysis:
#
# Delivery_person_Age
# Delivery_person_Ratings
# multiple_deliveries
# Festival
# Road_traffic_density
# Vehicle_condition
# Type_of_vehicle_motorcycle
# Type_of_vehicle_scooter
# These features exhibit a moderate correlation with Time_taken (min) and are likely to have a significant impact on the delivery time.

# %%
selected_columns = [
    'Delivery_person_Age',
    'Delivery_person_Ratings',
    'Restaurant_latitude',
    'Restaurant_longitude',
    'Delivery_location_latitude',
    'Delivery_location_longitude',
    'Weather_conditions_Cloudy',
                'Weather_conditions_Fog',
                'Weather_conditions_Sandstorms',
                'Weather_conditions_Stormy',
                'Weather_conditions_Sunny',
                'Weather_conditions_Windy',
    'multiple_deliveries',
    'Festival',
                'City',
    'Road_traffic_density',
    'Vehicle_condition',
    'Type_of_vehicle_bicycle',
                'Type_of_vehicle_electric_scooter',
    'Type_of_vehicle_motorcycle',
    'Type_of_vehicle_scooter',
    'distance',
    'Time_taken (min)'
]

# Creating a new DataFrame with the selected columns
new_data_frame = data[selected_columns]

# %%
new_data_frame
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                     36.0                      4.2            30.327968
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# ...

# %%
new_data_frame.to_csv("zomato_selected_features",index=False)

# %%
new_data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Weather_conditions_Cloudy         45584 non-null  int64
#  7   Weather_conditions_Fog            45584 non-null  int64
#  8   Weather_conditions_Sandstorms     45584 non-null  int64
#  9   Weather_conditions_Stormy         45584 non-null  int64
#  10  Weather_conditions_Sunny          45584 non-null  int64
# ...

# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
data_copy = pd.read_csv('zomato_selected_features')

# %%
data_copy.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Weather_conditions_Cloudy  \
# 0                    78.116106                          0
# 1                    76.347589                          0
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Delivery_person_Age               45584 non-null  float64
#  1   Delivery_person_Ratings           45584 non-null  float64
#  2   Restaurant_latitude               45584 non-null  float64
#  3   Restaurant_longitude              45584 non-null  float64
#  4   Delivery_location_latitude        45584 non-null  float64
#  5   Delivery_location_longitude       45584 non-null  float64
#  6   Weather_conditions_Cloudy         45584 non-null  int64
#  7   Weather_conditions_Fog            45584 non-null  int64
#  8   Weather_conditions_Sandstorms     45584 non-null  int64
#  9   Weather_conditions_Stormy         45584 non-null  int64
#  10  Weather_conditions_Sunny          45584 non-null  int64
# ...

# %%
data_copy.isnull().sum()
# Out:
# Delivery_person_Age                 0
# Delivery_person_Ratings             0
# Restaurant_latitude                 0
# Restaurant_longitude                0
# Delivery_location_latitude          0
# Delivery_location_longitude         0
# Weather_conditions_Cloudy           0
# Weather_conditions_Fog              0
# Weather_conditions_Sandstorms       0
# Weather_conditions_Stormy           0
# Weather_conditions_Sunny            0
# Weather_conditions_Windy            0
# multiple_deliveries                 0
# Festival                            0
# City                                0
# Road_traffic_density                0
# Vehicle_condition                   0
# Type_of_vehicle_bicycle             0
# Type_of_vehicle_electric_scooter    0
# Type_of_vehicle_motorcycle          0
# Type_of_vehicle_scooter             0
# distance                            0
# Time_taken (min)                    0
# dtype: int64

# %%
#This is for a show distributin and QQPlot diagram
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
import seaborn as sns
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,plot=pylab)
    plt.show()

# %%
for i in selected_columns:
    plot_data(data_copy[i])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
import seaborn as sns


# Function to plot histogram and QQ plot
def plot_data(sample, title):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample, kde=True)
    plt.title(f'Distribution of {title}')
    plt.subplot(1,2,2)
    stat.probplot(sample, plot=pylab)
    plt.title(f'QQ Plot of {title}')
    plt.show()

# Calculate z-scores and plot for each selected column
selected_columns = ['Delivery_person_Age',
    'Delivery_person_Ratings',
    'Restaurant_latitude',
    'Restaurant_longitude',
    'Delivery_location_latitude',
    'Delivery_location_longitude',
    # 'Time_Orderd_Hour',
    #             'Time_Orderd_Minute',
    # 'Time_Order_picked_Hour',
    #             'Time_Order_picked_Min',
    'Weather_conditions_Cloudy',
                'Weather_conditions_Fog',
                'Weather_conditions_Sandstorms',
                'Weather_conditions_Stormy',
                'Weather_conditions_Sunny',
                'Weather_conditions_Windy',
    'multiple_deliveries',
    'Festival',
                'City',
    'Road_traffic_density',
    'Vehicle_condition',
                'Type_of_vehicle_electric_scooter',
    'Type_of_vehicle_motorcycle',
    'Type_of_vehicle_scooter',
    'distance',
    'Time_taken (min)']  # Replace with your actual column names

for column in selected_columns:
    # Calculate z-scores
    z_scores = (data_copy[column] - data_copy[column].mean()) / data_copy[column].std()
    
    # Plot data
    plot_data(z_scores, f'Z-scores of {column}')

# %%
#Divide the dataset into independent and dependent dataset
X = data_copy.iloc[:,:-1] #Independent features
y = data_copy.iloc[:,-1]  #Dependent or Target feature

# %%
X
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                     36.0                      4.2            30.327968
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# ...

# %%
y
# Out:
# 0        46
# 1        23
# 2        21
# 3        20
# 4        41
#          ..
# 45579    32
# 45580    36
# 45581    16
# 45582    26
# 45583    36
# Name: Time_taken (min), Length: 45584, dtype: int64

# %%
#Divide the dataset into train and test dataset
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=30)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (31908, 22) (31908,)

# %%
y_test
# Out:
# 10074    30
# 12570    28
# 34085    20
# 30952    16
# 15574    38
#          ..
# 37781    42
# 32405    19
# 886      19
# 21049    17
# 29927    15
# Name: Time_taken (min), Length: 13676, dtype: int64

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
#It compute mean and standered deviation of the dataset
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
#These are the mean for Indepenedent features
scaler.mean_
# Out:
# array([2.95885205e+01, 4.63142308e+00, 1.70127207e+01, 7.01564954e+01,
#        1.74477779e+01, 7.07598973e+01, 1.66102545e-01, 1.81459195e-01,
#        1.63031215e-01, 1.65068321e-01, 1.60461326e-01, 1.63877398e-01,
#        7.73693118e-01, 2.00263257e-02, 4.45154820e-01, 1.73570891e+00,
#        1.02651373e+00, 1.37896452e-03, 8.40541557e-02, 5.79071079e-01,
#        3.35495800e-01, 9.71066340e+01])

# %%
#These are the standered deviation for Indepenedent features
scaler.scale_
# Out:
# array([5.68803497e+00, 3.28746249e-01, 8.18323783e+00, 2.29675933e+01,
#        7.36244784e+00, 2.12479510e+01, 3.72172661e-01, 3.85398178e-01,
#        3.69394150e-01, 3.71242199e-01, 3.67033362e-01, 3.70164283e-01,
#        5.98063137e-01, 1.40090228e-01, 8.29841391e-01, 9.30926331e-01,
#        8.38978673e-01, 3.71087992e-02, 2.77469016e-01, 4.93708177e-01,
#        4.72163497e-01, 1.08843516e+03])

# %%
#These is the zcore of Xtrain after tranform
X_train = scaler.transform(X_train)

# %%
X_train
# Out:
# array([[ 1.12718708, -1.61651449,  0.64737313, ...,  0.85258649,
#         -0.71055006, -0.07947569],
#        [-0.1034664 , -3.13744439,  0.64739721, ...,  0.85258649,
#         -0.71055006, -0.08086713],
#        [ 0.24814888,  0.51278737,  1.15614107, ..., -1.17290154,
#          1.40736038, -0.08647462],
#        ...,
#        [-1.68573515,  0.00715026,  0.67233343, ..., -1.17290154,
#          1.40736038, -0.07809184],
#        [ 0.7755718 , -0.09558459, -0.49398499, ...,  0.85258649,
#         -0.71055006, -0.08636389],
#        [-1.33411987,  0.20860139, -0.48319562, ...,  0.85258649,
#         -0.71055006, -0.08208606]])

# %%
X_train = pd.DataFrame(X_train)

# %%
X_train
# Out:
#              0         1         2         3         4         5         6   \
# 0      1.127187 -1.616514  0.647373  0.131167  0.669961  0.116679 -0.446305
# 1     -0.103466 -3.137444  0.647397  0.131248  0.668629  0.116295 -0.446305
# 2      0.248149  0.512787  1.156141  0.443938  1.228657  0.452410 -0.446305
# 3      0.599764 -1.312329 -0.226656  0.165206 -0.293358  0.156297 -0.446305
# 4      0.775572 -1.616514  0.258322  0.116402  0.230746  0.098366 -0.446305
# ...         ...       ...       ...       ...       ...       ...       ...
# 31903  1.302995  0.816973  1.156298  0.443508  1.228832  0.451945 -0.446305
# 31904 -0.279274  0.816973  0.051172  0.358934  0.004577  0.361939 -0.446305
# 31905 -1.685735  0.007150  0.672333  0.794024  0.699062  0.833653 -0.446305
# 31906  0.775572 -0.095585 -0.493985  0.326079 -0.605431  0.325013  2.240620
# 31907 -1.334120  0.208601 -0.483196  0.440083 -0.589364  0.449655 -0.446305
#
# ...

# %%
#It finds the z-score of Xtest takes mean and standered deviation of X_test
X_test=scaler.transform(X_test)

# %%
x_test = pd.DataFrame(X_test)

# %%
x_test
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.072341  0.512787 -0.493715  0.324443 -0.590190  0.328421 -0.446305
# 1     -0.982505  1.121159  1.209883  0.245853  1.293823  0.240176  2.240620
# 2     -0.279274 -0.095585  0.702518  0.249476  0.739403  0.247387 -0.446305
# 3     -0.630889 -0.399771  0.258322  0.116402  0.234820  0.099778 -0.446305
# 4     -0.003799  0.007150  0.701106  0.250194  0.729684  0.245339 -0.446305
# ...         ...       ...       ...       ...       ...       ...       ...
# 13671  0.248149 -3.137444 -2.078972 -3.054586 -2.360326 -3.326904 -0.446305
# 13672  0.775572 -0.399771  0.050114  0.361078  0.002043  0.363785 -0.446305
# 13673 -0.806697  0.208601  0.348792  0.224769  0.335376  0.216915 -0.446305
# 13674 -0.806697  0.512787 -0.572967  0.281687 -0.680994  0.281263 -0.446305
# 13675 -0.103466  0.512787 -0.496477  0.328414 -0.604126  0.328949 -0.446305
#
# ...

# %%
#Performing Linear Regression
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_regression.score(X_train,y_train)
# Out:
# 0.43810115992072685

# %%
#It show the unit movement in X-axis what is the movement with respect to Y-axis
linear_regression.coef_
# Out:
# array([ 2.23375333e+00, -2.48929022e+00, -4.07316810e-01, -9.77345345e-01,
#         4.33839376e-01,  9.11193986e-01, -4.91633047e+13, -5.09103706e+13,
#        -4.87962687e+13, -4.90403925e+13, -4.84844131e+13, -4.88980018e+13,
#         2.06741040e+00,  1.79555749e+00, -1.02470418e+00, -1.34249581e+00,
#        -1.74784675e+00, -4.17262287e+11, -3.11994347e+12, -5.55140041e+12,
#        -5.30914567e+12, -5.36972166e-01])

# %%
#It shows the when your x-axis =0 where your best fit line meet at y-axis is call intercept
linear_regression.intercept_
# Out:
# 26.3139432612246

# %%
#prediction of y based on X_test data
y_pred = linear_regression.predict(X_test)

# %%
print(y_pred)
# Out:
# [26.50790538 25.27715012 19.98231024 ... 21.4535497  21.93618427
#  16.93493027]

# %%
linear_regression.score(X_test,y_pred)
# Out:
# 1.0

# %%
import plotly.graph_objs as go
#Conclusion :
# 1] The regression model appears to capture the overall trend of the data but may struggle with certain data points, leading to larger prediction errors.
# 2] The presence of outliers suggests that the model's performance could be improved either by addressing these outliers or by using a more robust regression technique.
# 3] The jagged nature of the regression line indicates a close fit to the data points, which might be an issue if the model is overfitting.

# Assuming you have y_test and y_pred defined

# Assuming y_test and y_pred are already defined with 30 samples
y_test_sample = y_test[:50]
y_pred_sample = y_pred[:50]

# Convert range to list for x-axis
x_values = list(range(len(y_test_sample)))

# Create traces for actual and predicted data points
trace_actual = go.Scatter(x=x_values, y=y_test_sample, mode='markers', name='Actual', marker=dict(color='green'))
trace_predicted = go.Scatter(x=x_values, y=y_pred_sample, mode='markers', name='Predicted', marker=dict(color='red'))

# Create a trace for the regression line
trace_regression = go.Scatter(x=x_values, y=y_pred_sample, mode='lines', name='Regression line', line=dict(color='blue', width=2))

# Combine traces into a data list
data = [trace_actual, trace_predicted, trace_regression]

# Define layout for the plot
layout = go.Layout(
    title='Comparison of Actual and Predicted Data Points with Regression Line',
    xaxis=dict(title='Data Point Index'),
    yaxis=dict(title='y'),
    hovermode='closest',  # Show closest data point's values upon hover
)

# Create figure object that combines data and layout
fig = go.Figure(data=data, layout=layout)

# Display the interactive plot
fig.show()

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import numpy as np
def evaluate_model(true,predicted):
    mae=mean_absolute_error(true,predicted)
    mse=mean_squared_error(true,predicted)
    rmse= np.sqrt(mean_squared_error(true,predicted))
    r2_square=r2_score(true,predicted)
    return mae,mse,rmse,r2_square

# %%
##Train multiple models
from sklearn.linear_model import LinearRegression ,Lasso,Ridge,ElasticNet
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'ElasticNet':ElasticNet()

}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Prediction

    y_pred=model.predict(X_test)

    mae,mse,rmse,r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    

    print ('Model Training Performance')
    print ("RMSE:",rmse)
    print ("MAE :",mae )
    print("MSE :",mse)
    print("R2 score :",r2_square*100)

    r2_list.append(r2_square*100)

    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 7.066894937523725
# MAE : 5.644480622013981
# MSE : 49.941004057998455
# R2 score : 42.26134159507971
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 7.548834740512906
# MAE : 6.037698643724774
# MSE : 56.98490593957456
# R2 score : 34.117623777436826
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 7.067563335721719
# MAE : 5.644851226484664
# MSE : 49.95045150443791
# R2 score : 42.25041904970732
# ...
#
#
# ElasticNet
# Model Training Performance
# RMSE: 7.501296971311603
# MAE : 6.034374148901503
# MSE : 56.26945625180862
# R2 score : 34.944781859397914
# ...

# %%
linear_regression.score(X_train,y_train)
# Out:
# 0.43810115992072685

# %%
linear_regression.score(X_test,y_test)
# Out:
# 0.42261341595079716
